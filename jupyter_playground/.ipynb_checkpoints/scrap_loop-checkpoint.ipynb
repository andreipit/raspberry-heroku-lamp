# %%
import urllib3, time
http = urllib3.PoolManager()

def set_lamp(value):
    print('lamp now is:', value)
    return 

def send_to_web(value):
    if value==1:   http.request('GET', 'http://iot-flat-01.herokuapp.com/light_on_practice')
    elif value==0: http.request('GET', 'http://iot-flat-01.herokuapp.com/light_off_practice')
    print('sent to web:', value)
    return 

i = 0
while i < 10: 
    r = http.request('GET', 'https://iot-flat-01.herokuapp.com/min')
    lamp_out = int(str(r.data)[3562:3563])
    set_lamp(lamp_out)
    send_to_web(lamp_out)
    time.sleep(1)
    i+=1
# Out:
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 0
# sent to web: 0
# lamp now is: 0
# sent to web: 0
# lamp now is: 0
# sent to web: 0
# lamp now is: 0
# sent to web: 0
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 0
# sent to web: 0
# lamp now is: 0
# sent to web: 0
# lamp now is: 0
# sent to web: 0
# lamp now is: 0
# sent to web: 0
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# lamp now is: 1
# sent to web: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b45838e06133> in <module>
#      18     set_lamp(lamp_out)
#      19     send_to_web(lamp_out)
# ---> 20     time.sleep(1)
#      21     i+=1
#      22
#
# KeyboardInterrupt:

# %%
import datetime
str(datetime.datetime.now())
#datetime.datetime(2009, 1, 6, 15, 8, 24, 78915)

# print(datetime.datetime.now())
# 2009-01-06 15:08:24.789150
